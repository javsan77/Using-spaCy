# %%
# !pip install spacy
# !python -m spacy download en_core_web_md

# %%
import spacy

# %%
# Carga el modelo con embeddings preentrenados
nlp = spacy.load("en_core_web_md")

# %%
# Ejemplo de palabras
word1 = nlp("cat")  # "gato"
word2 = nlp("dog")  # "perro"
word3 = nlp("table")  # "mesa"

# %%
# Mostrar similitudes
print(f"Similitud entre 'cat' y 'dog': {word1.similarity(word2):.2f}")
print(f"Similitud entre 'cat' y 'table': {word1.similarity(word3):.2f}")
print(f"Similitud entre 'dog' y 'table': {word2.similarity(word3):.2f}")

# %%
 # Obtener el embedding (vector) de la palabra "cat"
vector = word1.vector
print(f"Embedding de 'cat':\n{vector}")
print(f"Tamaño del vector: {len(vector)}")

# %%
 sentence1 = nlp("The cat is sleeping.")  # "El gato está durmiendo."
sentence2 = nlp("The dog is playing.")  # "El perro está jugando."
sentence3 = nlp("The table is broken.")  # "La mesa está rota."

print(f"Similitud entre frases 1 y 2: {sentence1.similarity(sentence2):.2f}")
print(f"Similitud entre frases 1 y 3: {sentence1.similarity(sentence3):.2f}")
